# %% [markdown]
# ## We start by importing the necessary libraries for the EDA

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
from dython.nominal import associations
# %matplotlib inline

# %% [markdown]
# #### Now we load the clean data from the previous process

# %%
df = pd.read_csv("data-cleaned.csv")
df.head()
# Out:
#    Unnamed: 0  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0           0  Female              0     Yes         No       1           No
# 1           1    Male              0      No         No      34          Yes
# 2           2    Male              0      No         No       2          Yes
# 3           3    Male              0      No         No      45           No
# 4           4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# #### Let's view the columns of the Dataframe

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# #### As the first column adds no value to our analysis let's just drop it

# %%
df = df.drop('Unnamed: 0', axis=1)

# %% [markdown]
# #### Let's provide some Descriptive Statistics to summarize the central tendency, dispersion and shape of a dataset’s distribution for numerical fields. For the categorical fields check the "unique", "top" and "freq".

# %%
df.describe(include = 'all')
# Out:
#        gender  SeniorCitizen Partner Dependents       tenure PhoneService  \
# count    7032    7032.000000    7032       7032  7032.000000         7032
# unique      2            NaN       2          2          NaN            2
# top      Male            NaN      No         No          NaN          Yes
# freq     3549            NaN    3639       4933          NaN         6352
# mean      NaN       0.162400     NaN        NaN    32.421786          NaN
# std       NaN       0.368844     NaN        NaN    24.545260          NaN
# min       NaN       0.000000     NaN        NaN     1.000000          NaN
# 25%       NaN       0.000000     NaN        NaN     9.000000          NaN
# 50%       NaN       0.000000     NaN        NaN    29.000000          NaN
# 75%       NaN       0.000000     NaN        NaN    55.000000          NaN
# max       NaN       1.000000     NaN        NaN    72.000000          NaN
#
#        MultipleLines InternetService OnlineSecurity OnlineBackup  \
# ...

# %% [markdown]
# #### Viewing the unique values for each column

# %%
for col in df:
    print(df[col].unique())
# Out:
# ['Female' 'Male']
# [0 1]
# ['Yes' 'No']
# ['No' 'Yes']
# [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# ['No' 'Yes']
# ['No phone service' 'No' 'Yes']
# ['DSL' 'Fiber optic' 'No']
# ['No' 'Yes' 'No internet service']
# ['Yes' 'No' 'No internet service']
# ['No' 'Yes' 'No internet service']
# ['No' 'Yes' 'No internet service']
# ['No' 'Yes' 'No internet service']
# ['No' 'Yes' 'No internet service']
# ['Month-to-month' 'One year' 'Two year']
# ['Yes' 'No']
# ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# ['No' 'Yes']

# %% [markdown]
# #### Some of the columns have no internet service or no phone service, that can be replaced with a simple No

# %%
df.replace('No internet service','No',inplace=True)
df.replace('No phone service','No',inplace=True)

# %% [markdown]
# #### Now let's visualise the data using MatPlotLib
# ##### First, we compare the number of customers who churnned or not with their tenure with the company

# %%
tenure_churn_no = df[df.Churn=='No'].tenure
tenure_churn_yes = df[df.Churn=='Yes'].tenure

plt.xlabel("tenure")
plt.ylabel("Number Of Customers")
plt.title("Customer Churn Prediction Visualiztion")

plt.hist([tenure_churn_yes, tenure_churn_no], rwidth=0.95, color=['green','red'],label=['Churn=Yes','Churn=No'])
plt.legend()

# %%
df_copy = df.copy()

# %%
df_gender = df_copy[df_copy.Churn=="Yes"].groupby('gender').size()

# %% [markdown]
# ##### - Which gender churned the most?

# %%
labels = ['Female','Male']

#define Seaborn color palette to use
colors = sns.color_palette('bright')[0:5]
sns.set_theme(context='poster', palette="dark", font="arial", font_scale= 1.5)

#create pie chart
plt.pie(df_gender, labels = labels, colors = colors, autopct='%.0f%%')
plt.show()

# %% [markdown]
# #### Let's plot the number of churned customers and their monthly charges

# %%
mc_churn_no = df[df.Churn=='No'].MonthlyCharges      
mc_churn_yes = df[df.Churn=='Yes'].MonthlyCharges      

plt.xlabel("Monthly Charges")
plt.ylabel("Number Of Customers")
plt.title("Customers Churned and Their Monthly Charges")


plt.hist([mc_churn_yes, mc_churn_no], rwidth=0.95, color=['green','red'],label=['Churn=Yes','Churn=No'])
plt.legend()
plt.show()

# %% [markdown]
# ##### - Tenure of the churned customers from more to less

# %%
df2 = df_copy[df_copy.Churn == 'Yes']
df3 = df2['tenure'].value_counts(ascending=False).reset_index()
df3. rename(columns = {'index':'tenure (months)', 'tenure':'num of customers'}, inplace = True)
df3.head(72)
# Out:
#     tenure (months)  num of customers
# 0                 1               380
# 1                 2               123
# 2                 3                94
# 3                 4                83
# 4                 5                64
# ..              ...               ...
# 67               60                 6
# 68               72                 6
# 69               62                 5
# 70               64                 4
# 71               63                 4
#
# [72 rows x 2 columns]

# %%
sns.set_theme(context='notebook', palette="dark", font="arial", font_scale= 1)
plt.figure(figsize=(20,8))
sns.barplot(data = df3,x = 'tenure (months)',y = 'num of customers')
plt.show()

# %% [markdown]
# #### Let's explore the association among our categorical features using Cramer's V and Theil's U

# %%
cat_df = df.select_dtypes(include=['object']).copy()

# %%
cat_df
# Out:
#       gender Partner Dependents PhoneService MultipleLines InternetService  \
# 0     Female     Yes         No           No            No             DSL
# 1       Male      No         No          Yes            No             DSL
# 2       Male      No         No          Yes            No             DSL
# 3       Male      No         No           No            No             DSL
# 4     Female      No         No          Yes            No     Fiber optic
# ...      ...     ...        ...          ...           ...             ...
# 7027    Male     Yes        Yes          Yes           Yes             DSL
# 7028  Female     Yes        Yes          Yes           Yes     Fiber optic
# 7029  Female     Yes        Yes           No            No             DSL
# 7030    Male     Yes         No          Yes           Yes     Fiber optic
# 7031    Male      No         No          Yes            No     Fiber optic
#
# ...

# %%
associations(cat_df, nominal_columns = 'all', nom_nom_assoc = 'cramer', figsize = (15, 10))
# Out:
# {'corr':                     gender   Partner  Dependents  PhoneService  MultipleLines  \
#  gender            1.000000  0.000000    0.000000      0.000000       0.000000
#  Partner           0.000000  1.000000    0.451833      0.013371       0.141783
#  Dependents        0.000000  0.451833    1.000000      0.000000       0.020820
#  PhoneService      0.000000  0.013371    0.000000      1.000000       0.278807
#  MultipleLines     0.000000  0.141783    0.020820      0.278807       1.000000
#  InternetService   0.000000  0.000000    0.177625      0.451973       0.368858
#  OnlineSecurity    0.010687  0.142543    0.079559      0.090366       0.097554
#  OnlineBackup      0.004632  0.141057    0.020032      0.050235       0.201587
#  DeviceProtection  0.000000  0.152803    0.006480      0.068544       0.201091
#  TechSupport       0.000000  0.119306    0.061571      0.093860       0.099398
#  StreamingTV       0.000000  0.123625    0.010934      0.017150       0.257250
# ...

# %%
associations(cat_df, nominal_columns = 'all', nom_nom_assoc = 'theil', figsize = (15, 10))
# Out:
# {'corr':                         gender       Partner  Dependents  PhoneService  \
#  gender            1.000000e+00  1.371933e-06    0.000077  4.074911e-05
#  Partner           1.373058e-06  1.000000e+00    0.156814  2.447646e-04
#  Dependents        8.785500e-05  1.781542e-01    1.000000  9.520303e-07
#  PhoneService      8.887901e-05  5.334254e-04    0.000002  1.000000e+00
#  MultipleLines     5.793948e-05  1.496433e-02    0.000435  8.333702e-02
#  InternetService   5.922468e-05  7.699480e-07    0.015053  1.072175e-01
#  OnlineSecurity    2.225214e-04  1.720882e-02    0.005344  6.590527e-03
#  OnlineBackup      1.330486e-04  1.565852e-02    0.000432  2.054662e-03
#  DeviceProtection  5.056531e-07  1.838030e-02    0.000150  3.688648e-03
#  TechSupport       6.008358e-05  1.201908e-02    0.003251  7.057281e-03
#  StreamingTV       3.809572e-05  1.165154e-02    0.000205  3.402600e-04
#  StreamingMovies   7.643470e-05  1.045740e-02    0.001109  8.286888e-04
# ...

# %% [markdown]
# ##### - The most common service among churned customers

# %%
services_y = df[df.Churn == 'Yes'].iloc[:, 5:-6]
services_y
# Out:
#      PhoneService MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 2             Yes            No             DSL            Yes          Yes
# 4             Yes            No     Fiber optic             No           No
# 5             Yes           Yes     Fiber optic             No           No
# 8             Yes           Yes     Fiber optic             No           No
# 13            Yes           Yes     Fiber optic             No          Yes
# ...           ...           ...             ...            ...          ...
# 7010          Yes            No             DSL             No           No
# 7015          Yes            No             DSL             No           No
# 7021          Yes           Yes     Fiber optic             No           No
# 7023          Yes           Yes     Fiber optic            Yes          Yes
# 7030          Yes           Yes     Fiber optic             No           No
#
# ...

# %%
churn_services = services_y[services_y != 'No'].count().sort_values(ascending = False)
churn_services
# Out:
# InternetService     1756
# PhoneService        1699
# MultipleLines        850
# StreamingMovies      818
# StreamingTV          814
# DeviceProtection     545
# OnlineBackup         523
# TechSupport          310
# OnlineSecurity       295
# dtype: int64

# %%
fig, ax = plt.subplots(figsize = (21,5))
ax.bar(churn_services.index,
        churn_services.values)
ax.set_ylabel("Churned Customers", size = 15)
ax.set_title("Top Services utilized by Churned Customers", size = 17)
for i in range(len(churn_services.index)):
    plt.text(i, churn_services.values[i], churn_services.values[i], ha = 'center', va = 'bottom')
plt.show()

# %% [markdown]
# ##### - The most common service among non-churned customers

# %%
services_n = df[df.Churn == 'No'].iloc[:, 5:-6]
services_n
# Out:
#      PhoneService MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0              No            No             DSL             No          Yes
# 1             Yes            No             DSL            Yes           No
# 3              No            No             DSL            Yes           No
# 6             Yes           Yes     Fiber optic             No          Yes
# 7              No            No             DSL            Yes           No
# ...           ...           ...             ...            ...          ...
# 7026          Yes            No              No             No           No
# 7027          Yes           Yes             DSL            Yes           No
# 7028          Yes           Yes     Fiber optic             No          Yes
# 7029           No            No             DSL            Yes           No
# 7031          Yes            No     Fiber optic            Yes           No
#
# ...

# %%
nonchurn_services = services_n[services_n != 'No'].count().sort_values(ascending = False)
nonchurn_services
# Out:
# PhoneService        4653
# InternetService     3756
# MultipleLines       2117
# StreamingMovies     1913
# OnlineBackup        1902
# StreamingTV         1889
# DeviceProtection    1873
# TechSupport         1730
# OnlineSecurity      1720
# dtype: int64

# %%
fig, ax = plt.subplots(figsize = (21,5))
ax.bar(nonchurn_services.index,
        nonchurn_services.values)
ax.set_ylabel("Non-Churned Customers", size = 15)
ax.set_title("Top Services utilized by Non-Churned Customers", size = 17)
for i in range(len(churn_services.index)):
    plt.text(i, nonchurn_services.values[i], nonchurn_services.values[i], ha = 'center', va = 'bottom')
plt.show()

# %% [markdown]
# ##### - Monthly revenue lost by losing the churned customers

# %%
df[df.Churn != 'Yes'].MonthlyCharges.sum()
# Out:
# 316530.15

# %% [markdown]
# ##### - Percentage of churned customers with DSL internet service

# %%
print((df[(df.Churn != 'Yes') & (df.InternetService == 'DSL')].InternetService.count() / df[df.Churn != 'Yes'].InternetService.count())*100, '%')
# Out:
# 37.9043191942669 %

# %% [markdown]
# ##### - Percentage of churned customers with Fiber Optic internet service

# %%
print((df[(df.Churn != 'Yes') & (df.InternetService == 'Fiber optic')].InternetService.count() / df[df.Churn != 'Yes'].InternetService.count())*100, '%')
# Out:
# 34.84408289754019 %

# %% [markdown]
# ##### - What is the percentage of churned customers among the top 100 Total charged customers

# %%
top_100 = df.sort_values('TotalCharges')[:100]
top_100
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 1649    Male              0     Yes        Yes       1          Yes
# 6480    Male              0      No         No       1          Yes
# 1147  Female              0      No         No       1          Yes
# 4931    Male              0      No         No       1          Yes
# 582   Female              0     Yes        Yes       1          Yes
# ...      ...            ...     ...        ...     ...          ...
# 4951  Female              0     Yes        Yes       1          Yes
# 4365    Male              0     Yes        Yes       1          Yes
# 2078  Female              0      No         No       1          Yes
# 22      Male              0      No         No       1          Yes
# 2129  Female              0      No         No       1          Yes
#
#      MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 1649            No              No             No           No
# ...

# %%
print((top_100[top_100.Churn == 'Yes'].Churn.count() / top_100.Churn.count()) * 100, '%')
# Out:
# 35.0 %

# %% [markdown]
# ##### - What is the percentage of churned customers among the top 100 monthly charged customers

# %%
top_100_monthly = df.sort_values('MonthlyCharges')[:100]
top_100_monthly
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 3713    Male              0      No         No      28          Yes
# 1524  Female              0     Yes         No      59          Yes
# 6643    Male              0      No         No      36          Yes
# 1152  Female              0      No         No      53          Yes
# 6895  Female              0     Yes        Yes      25          Yes
# ...      ...            ...     ...        ...     ...          ...
# 5133    Male              0      No         No       5          Yes
# 5637    Male              0      No        Yes       1          Yes
# 2819    Male              0     Yes         No      63          Yes
# 6242  Female              0     Yes        Yes       1          Yes
# 4659  Female              0     Yes         No      20          Yes
#
#      MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 3713            No              No             No           No
# ...

# %%
print((top_100_monthly[top_100_monthly.Churn == 'Yes'].Churn.count() / top_100_monthly.Churn.count()) * 100, '%')
# Out:
# 7.000000000000001 %

# %% [markdown]
# #### Finally as we had to make some changes to the Dataframe we have to export the new version of the dataset to use it the model building phase

# %%
df.to_csv("data-ready.csv")
